# %%
from google.colab import files
uploaded_files= files.upload()
# Out:
#      <input type="file" id="files-35d09a5c-35e7-4625-a0fd-bb8f32dfdc52" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35d09a5c-35e7-4625-a0fd-bb8f32dfdc52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving file_data.csv to file_data.csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import io
# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.7.0

# %%
#clinic_data = pd.read_csv(io.BytesIO(uploaded_files['file_data.csv']))
raw_dataset = pd.read_csv(io.BytesIO(uploaded_files['file_data.csv']), names=column_names,na_values='?', comment='\t',sep=' ', skipinitialspace=True)
column_names = clinic_data.columns
print(raw_dataset)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Salient Feature  ... Year fou
# ...

# %% [markdown]
# # New Section

# %%
clinic_data = raw_dataset.copy()
clinic_data.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                              Salient Feature  ... Year founded
# Transcarent,3,3,"consumers, employers,                                         payers",2,None,4,1,1,3,3,4,"Rapid   access     to                    healthcare through any      device, contracted               for                 low or  zero cost through payers",104.29,0,2020 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN             NaN  ...          NaN
# ...

# %%
clinic_data.isna().sum()
# Out:
# Salient Feature                                               0
# Ease of clinical integration (1-4 : easiest)                  0
# Sectors of Healthcare Affected (1-4 : many)                   0
# Key Customers                                                 0
# Robustness of underlying technology (1-4 : robust)            0
# Underlying 'AI'                                               0
# Patient Facing Strength (1-4 : highly visible)                0
# E : Access to Proprietary Data (1-4 : difficult to access)    0
# T/L : Transformation and Loading (1-4 : stated goal)          0
# First Mover Advantage (1-4 : first on scene)                  0
# Regulatory Difficulty (1-4 : high)                            0
# Ability to showcase value (1 - 4: quickly)                    0
# Proposed Secret?                                              0
# Valuation                                                     0
# Binary Label                                                  0
# ...

# %%
clinic_data = clinic_data.dropna()
clinic_data.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f98b38934140> in <cell line: 1>()
# ----> 1 clinic_data = clinic_data.dropna()
#       2 clinic_data.tail()
#
# NameError: name 'clinic_data' is not defined

# %%
train_dataset = clinic_data.sample(frac=0.8, random_state=0)
test_dataset = clinic_data.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['Ability to showcase value (1 - 4: quickly)', 'Year founded']], diag_kind='kde')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-cefbfc73a650> in <module>()
# ----> 1 sns.pairplot(train_dataset[['Ability to showcase value (1 - 4: quickly)', 'Year founded']], diag_kind='kde')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
# ...
